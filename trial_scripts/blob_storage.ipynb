# %%
import os
from azure.storage.blob import BlobServiceClient

# %%
# Replace with your actual connection string and container name
connection_string = "XXXXXXXXXXXXXXXXXX"
container_name = "XXX"
blob_name = "XXxxsss"

# %%
# 1. Create the BlobServiceClient
blob_service_client = BlobServiceClient.from_connection_string(connection_string)

# 2. Get a client for the specific blob
blob_client = blob_service_client.get_blob_client(container=container_name, blob=blob_name)

# 3. Upload the local file
with open("C:\\Users\\ansul\\OneDrive\\Documents\\Dear Sir.docx", "rb") as data:
    blob_client.upload_blob(data, overwrite=True)

print(f"File  uploaded to {blob_name} successfully.")
# Out:
# File  uploaded to uploaded_file.txt successfully.
